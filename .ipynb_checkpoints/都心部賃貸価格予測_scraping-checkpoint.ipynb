# %% [markdown]
# ### データの収集
# ### 東京都港区、東京都新宿区、東京都渋谷区、東京都品川区、東京都目黒区の賃貸住宅

# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

import time

# %%
#１つの建物の情報
all_data=[]
max_page=920
suumo_url='https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ta=13&sc=13103&sc=13104&sc=13113&sc=13109&sc=13110&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&srch_navi=1&page={}'

s=time.time()
def get_html(url):
    res=requests.get(url)
    soup=BeautifulSoup(res.content, "html.parser")
    return soup

for page in range(1, max_page+1):
    url=suumo_url.format(page)
    soup=get_html(url)
    #読み込みによるサーバーダウンを防ぐために一時中断(2022/09/30: 追加)
    time.sleep(1)
    items=soup.find_all('div', class_="cassetteitem")
    
    
    for item in items:    
        #各物件に関して、物件情報の共通項目：最寄駅
        stations=item.find_all('div', class_="cassetteitem_detail-text")

        base_data={}
        base_data['物件名']=item.find('div', class_="cassetteitem_content-title").text
        base_data['カテゴリー']=item.find('div', class_="cassetteitem_content-label").text
        base_data['住所']=item.find('li', class_="cassetteitem_detail-col1").text
        base_data['最寄駅0']=stations[0].text
        base_data['最寄駅1']=stations[1].text
        base_data['最寄駅2']=stations[2].text   
        base_data['築年数']=item.find('li', class_="cassetteitem_detail-col3").find_all('div')[0].text
        base_data['構造']=item.find('li', class_="cassetteitem_detail-col3").find_all('div')[1].text


        #各部屋に関して
        tbodys=item.find('table', class_="cassetteitem_other").find_all('tbody')

        for i,tbody in enumerate(tbodys):
            data=base_data.copy()

            data['階数']=tbody.find_all('td')[2].getText().strip()
            data['賃料']=tbody.find('span', class_="cassetteitem_other-emphasis ui-text--bold").getText().strip()
            data['管理費']=tbody.find('span', class_="cassetteitem_price cassetteitem_price--administration").getText().strip()
            data['敷金']=tbody.find('span', class_="cassetteitem_price cassetteitem_price--deposit").getText().strip()
            data['礼金']=tbody.find('span', class_="cassetteitem_price cassetteitem_price--gratuity").getText().strip()
            data['間取り']=tbody.find('span', class_="cassetteitem_madori").getText().strip()
            data['面積']=tbody.find('span', class_="cassetteitem_menseki").getText().strip()

            all_data.append(data)    

df=pd.DataFrame(all_data)
e=time.time()

print('処理時間：', e-s)
# Out:
# 処理時間： 3761.5459220409393

# %%
df
# Out:
#                       物件名    カテゴリー          住所  \
# 0      ＪＲ山手線 大崎駅 3階建 築45年  賃貸マンション  東京都品川区北品川５
# 1             ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町
# 2             ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町
# 3             ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町
# 4             ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町
# ...                   ...      ...         ...
# 61103          ビレッジハウス八潮2  賃貸マンション   東京都品川区八潮５
# 61104          ビレッジハウス八潮3  賃貸マンション   東京都品川区八潮５
# 61105              原町アパート   賃貸アパート   東京都新宿区原町３
# 61106              原町アパート   賃貸アパート   東京都新宿区原町３
# 61107              原町アパート   賃貸アパート   東京都新宿区原町３
#
#                                      最寄駅0                 最寄駅1  \
# 0                          ＪＲ山手線/大崎駅 歩10分        京急本線/北品川駅 歩9分
# 1                     東京メトロ有楽町線/江戸川橋駅 歩3分    東京メトロ東西線/神楽坂駅 歩6分
# 2                     東京メトロ有楽町線/江戸川橋駅 歩3分    東京メトロ東西線/神楽坂駅 歩6分
# 3                     東京メトロ有楽町線/江戸川橋駅 歩3分    東京メトロ東西線/神楽坂駅 歩6分
# 4                     東京メトロ有楽町線/江戸川橋駅 歩3分    東京メトロ東西線/神楽坂駅 歩6分
# ...                                   ...                  ...
# 61103  りんかい線/品川シーサイド駅 バス6分 (バス停)八潮公園前 歩1分  りんかい線/品川シーサイド駅 歩14分
# 61104  りんかい線/品川シーサイド駅 バス6分 (バス停)八潮公園前 歩1分  りんかい線/品川シーサイド駅 歩14分
# 61105                  東京メトロ東西線/神楽坂駅 歩20分     都営大江戸線/牛込柳町駅 歩4分
# 61106                  東京メトロ東西線/神楽坂駅 歩20分     都営大江戸線/牛込柳町駅 歩4分
# 61107                  東京メトロ東西線/神楽坂駅 歩20分     都営大江戸線/牛込柳町駅 歩4分
#
#                        最寄駅2   築年数    構造   階数      賃料     管理費      敷金      礼金  \
# 0            京急本線/新馬場駅 歩11分  築45年   3階建   2階  10.9万円       -  10.9万円  10.9万円
# 1        都営大江戸線/牛込神楽坂駅 歩13分  築12年   8階建   5階    10万円   5000円    10万円    10万円
# 2        都営大江戸線/牛込神楽坂駅 歩13分  築12年   8階建   7階    11万円   5000円    11万円    11万円
# 3        都営大江戸線/牛込神楽坂駅 歩13分  築12年   8階建   8階  14.5万円  10000円  14.5万円  14.5万円
# 4        都営大江戸線/牛込神楽坂駅 歩13分  築12年   8階建   1階    15万円  10000円       -       -
# ...                     ...   ...   ...  ...     ...     ...     ...     ...
# 61103  東京モノレール/大井競馬場前駅 歩18分  築38年  16階建   3階  11.2万円       -       -       -
# 61104  東京モノレール/大井競馬場前駅 歩20分  築38年  16階建  14階  11.8万円       -       -       -
# 61105      都営大江戸線/若松河田駅 歩9分  築54年   2階建   1階     6万円       -     6万円       -
# 61106      都営大江戸線/若松河田駅 歩9分  築54年   2階建   1階     6万円       -     6万円       -
# 61107      都営大江戸線/若松河田駅 歩9分  築54年   2階建   2階   6.1万円       -   6.1万円       -
#
#          間取り       面積
# 0      11LDK     40m2
# 1         1K  25.65m2
# 2         1K  25.65m2
# 3       1LDK  41.08m2
# 4        1SK  41.86m2
# ...      ...      ...
# 61103    3DK  61.62m2
# 61104    3DK  61.62m2
# 61105  ワンルーム  22.68m2
# 61106  ワンルーム  20.36m2
# 61107  ワンルーム     21m2
#
# [61108 rows x 15 columns]

# %%
#csvファイルで保存
df.to_csv('sample_data_city.csv', index=None)

# %%
#試しに読み込み
df_sample=pd.read_csv('sample_data_city.csv')
df_sample.head()
# Out:
#                   物件名    カテゴリー          住所                 最寄駅0  \
# 0  ＪＲ山手線 大崎駅 3階建 築45年  賃貸マンション  東京都品川区北品川５       ＪＲ山手線/大崎駅 歩10分
# 1         ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町  東京メトロ有楽町線/江戸川橋駅 歩3分
# 2         ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町  東京メトロ有楽町線/江戸川橋駅 歩3分
# 3         ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町  東京メトロ有楽町線/江戸川橋駅 歩3分
# 4         ステージグランデ神楽坂  賃貸マンション   東京都新宿区改代町  東京メトロ有楽町線/江戸川橋駅 歩3分
#
#                 最寄駅1                最寄駅2   築年数   構造  階数      賃料     管理費  \
# 0      京急本線/北品川駅 歩9分      京急本線/新馬場駅 歩11分  築45年  3階建  2階  10.9万円       -
# 1  東京メトロ東西線/神楽坂駅 歩6分  都営大江戸線/牛込神楽坂駅 歩13分  築12年  8階建  5階    10万円   5000円
# 2  東京メトロ東西線/神楽坂駅 歩6分  都営大江戸線/牛込神楽坂駅 歩13分  築12年  8階建  7階    11万円   5000円
# 3  東京メトロ東西線/神楽坂駅 歩6分  都営大江戸線/牛込神楽坂駅 歩13分  築12年  8階建  8階  14.5万円  10000円
# 4  東京メトロ東西線/神楽坂駅 歩6分  都営大江戸線/牛込神楽坂駅 歩13分  築12年  8階建  1階    15万円  10000円
#
#        敷金      礼金    間取り       面積
# 0  10.9万円  10.9万円  11LDK     40m2
# 1    10万円    10万円     1K  25.65m2
# 2    11万円    11万円     1K  25.65m2
# 3  14.5万円  14.5万円   1LDK  41.08m2
# 4       -       -    1SK  41.86m2

# %%
df_sample.shape
# Out:
# (61108, 15)
